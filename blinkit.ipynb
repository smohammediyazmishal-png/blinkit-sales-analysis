# %%
import pandas as pd

# %%
import numpy as np

# %%
orders = pd.read_csv(r"C:\Users\Huawei\Desktop\data science\project resume\zepto\archive\blinkit_orders.csv")

# %%
order_items = pd.read_csv(r"C:\Users\Huawei\Desktop\data science\project resume\zepto\archive\blinkit_order_items.csv")

# %%
products = pd.read_csv(r"C:\Users\Huawei\Desktop\data science\project resume\zepto\archive\blinkit_products.csv")

# %%
customers = pd.read_csv(r"C:\Users\Huawei\Desktop\data science\project resume\zepto\archive\blinkit_customers.csv")

# %%
orders.head()
# Out:
#      order_id  customer_id           order_date promised_delivery_time  \
# 0  1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1  1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2  9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3  9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4  5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:01         On Time      3197.07           Cash
# 1  2024-05-28 13:27:29         On Time       976.55           Cash
# 2  2024-09-23 13:29:12         On Time       839.05            UPI
# 3  2023-11-24 16:33:56         On Time       440.23           Card
# 4  2023-11-20 05:18:39         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# ...

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'blinkit.ipynb',
#  'blinkit_customers.csv',
#  'blinkit_customer_feedback.csv',
#  'blinkit_delivery_performance.csv',
#  'blinkit_inventory.csv',
#  'blinkit_inventoryNew.csv',
#  'blinkit_marketing_performance.csv',
#  'blinkit_orders.csv',
#  'blinkit_order_items.csv',
#  'blinkit_products.csv',
#  'Category_Icons.xlsx',
#  'Rating_Icon.xlsx']

# %%
order_items.head()
# Out:
#      order_id  product_id  quantity  unit_price
# 0  1961864118      642612         3      517.03
# 1  1549769649      378676         1      881.42
# 2  9185164487      741341         2      923.84
# 3  9644738826      561860         1      874.78
# 4  5427684290      602241         2      976.55

# %%
orders.columns
order_items.columns
products.columns
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'email', 'phone', 'address', 'area',
#        'pincode', 'registration_date', 'customer_segment', 'total_orders',
#        'avg_order_value'],
#       dtype='object')

# %%
df = pd.merge(order_items, orders, on="order_id")

# %%
df.head()
# Out:
#      order_id  product_id  quantity  unit_price  customer_id  \
# 0  1961864118      642612         3      517.03     30065862
# 1  1549769649      378676         1      881.42      9573071
# 2  9185164487      741341         2      923.84     45477575
# 3  9644738826      561860         1      874.78     88067569
# 4  5427684290      602241         2      976.55     83298567
#
#             order_date promised_delivery_time actual_delivery_time  \
# 0  2024-07-17 08:34:01    2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  2024-05-28 13:14:29    2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  2024-09-23 13:07:12    2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  2023-11-24 16:16:56    2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  2023-11-20 05:00:39    2023-11-20 05:17:39  2023-11-20 05:18:39
#
#   delivery_status  order_total payment_method  delivery_partner_id  store_id
# 0         On Time      3197.07           Cash                63230      4771
# ...

# %%
df = pd.merge(df, products, on="product_id")

# %%
df.head()
# Out:
#      order_id  product_id  quantity  unit_price  customer_id  \
# 0  1961864118      642612         3      517.03     30065862
# 1  1549769649      378676         1      881.42      9573071
# 2  9185164487      741341         2      923.84     45477575
# 3  9644738826      561860         1      874.78     88067569
# 4  5427684290      602241         2      976.55     83298567
#
#             order_date promised_delivery_time actual_delivery_time  \
# 0  2024-07-17 08:34:01    2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  2024-05-28 13:14:29    2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  2024-09-23 13:07:12    2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  2023-11-24 16:16:56    2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  2023-11-20 05:00:39    2023-11-20 05:17:39  2023-11-20 05:18:39
#
#   delivery_status  order_total  ... store_id  product_name  \
# 0         On Time      3197.07  ...     4771    Pet Treats
# 1         On Time       976.55  ...     7534  Orange Juice
# ...

# %%
df = pd.merge(df, customers, on="customer_id")

# %%
df.head()
# Out:
#      order_id  product_id  quantity  unit_price  customer_id  \
# 0  1961864118      642612         3      517.03     30065862
# 1  1549769649      378676         1      881.42      9573071
# 2  9185164487      741341         2      923.84     45477575
# 3  9644738826      561860         1      874.78     88067569
# 4  5427684290      602241         2      976.55     83298567
#
#             order_date promised_delivery_time actual_delivery_time  \
# 0  2024-07-17 08:34:01    2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  2024-05-28 13:14:29    2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  2024-09-23 13:07:12    2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  2023-11-24 16:16:56    2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  2023-11-20 05:00:39    2023-11-20 05:17:39  2023-11-20 05:18:39
#
#   delivery_status  order_total  ...     customer_name  \
# 0         On Time      3197.07  ...   Urishilla Hegde
# 1         On Time       976.55  ...     Ranveer Mahal
# ...

# %%
df["Total_Sales"] = df["quantity"] * df["price"]

# %%
df.head()
# Out:
#      order_id  product_id  quantity  unit_price  customer_id  \
# 0  1961864118      642612         3      517.03     30065862
# 1  1549769649      378676         1      881.42      9573071
# 2  9185164487      741341         2      923.84     45477575
# 3  9644738826      561860         1      874.78     88067569
# 4  5427684290      602241         2      976.55     83298567
#
#             order_date promised_delivery_time actual_delivery_time  \
# 0  2024-07-17 08:34:01    2024-07-17 08:52:01  2024-07-17 08:47:01
# 1  2024-05-28 13:14:29    2024-05-28 13:25:29  2024-05-28 13:27:29
# 2  2024-09-23 13:07:12    2024-09-23 13:25:12  2024-09-23 13:29:12
# 3  2023-11-24 16:16:56    2023-11-24 16:34:56  2023-11-24 16:33:56
# 4  2023-11-20 05:00:39    2023-11-20 05:17:39  2023-11-20 05:18:39
#
#   delivery_status  order_total  ...                     email         phone  \
# 0         On Time      3197.07  ...          ydeo@example.org  910400446367
# ...

# %%
df["Total_Sales"].sum()
# Out:
# np.float64(4972415.43)

# %%
df.groupby("product_name")["Total_Sales"].sum().sort_values(ascending=False).head(10)
# Out:
# product_name
# Vitamins          260822.01
# Pet Treats        252007.37
# Cough Syrup       203569.98
# Toilet Cleaner    199837.48
# Bread             184851.10
# Dish Soap         184441.21
# Cat Food          166596.39
# Baby Wipes        158768.41
# Onions            138858.42
# Baby Food         137442.79
# Name: Total_Sales, dtype: float64

# %%
df.groupby("category")["Total_Sales"].sum()
# Out:
# category
# Baby Care                348227.18
# Cold Drinks & Juices     392717.62
# Dairy & Breakfast        639222.19
# Fruits & Vegetables      559053.08
# Grocery & Staples        359937.82
# Household Care           444244.25
# Instant & Frozen Food    307212.65
# Personal Care            394894.61
# Pet Care                 539888.75
# Pharmacy                 592368.57
# Snacks & Munchies        394648.71
# Name: Total_Sales, dtype: float64

# %%
df.columns
# Out:
# Index(['order_id', 'product_id', 'quantity', 'unit_price', 'customer_id',
#        'order_date', 'promised_delivery_time', 'actual_delivery_time',
#        'delivery_status', 'order_total', 'payment_method',
#        'delivery_partner_id', 'store_id', 'product_name', 'category', 'brand',
#        'price', 'mrp', 'margin_percentage', 'shelf_life_days',
#        'min_stock_level', 'max_stock_level', 'customer_name', 'email', 'phone',
#        'address', 'area', 'pincode', 'registration_date', 'customer_segment',
#        'total_orders', 'avg_order_value', 'Total_Sales'],
#       dtype='object')

# %%
df.groupby("area")["Total_Sales"].sum()
# Out:
# area
# Adoni            19501.09
# Agartala         21911.48
# Agra             32294.65
# Ahmedabad         9029.36
# Ahmednagar       30887.71
#                    ...
# Vijayanagaram     5714.51
# Vijayawada       10384.98
# Visakhapatnam    13502.05
# Warangal         13023.04
# Yamunanagar      21940.10
# Name: Total_Sales, Length: 316, dtype: float64

# %%
df.to_csv("zepto_dashboard_data.csv", index=False)
